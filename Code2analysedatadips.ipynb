# %%
# Out:
# ...
#   Using cached pandas-3.0.3.tar.gz (4.7 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × installing build dependencies for pandas did not run successfully.
#   │ exit code: 1
#   ╰─> [54 lines of output]
# ...
#         Using cached meson_python-0.19.0-py3-none-any.whl.metadata (2.1 kB)
# ...
#         Using cached meson-1.11.1-py3-none-any.whl.metadata (1.8 kB)
# ...
#         Using cached wheel-0.47.0-py3-none-any.whl.metadata (2.3 kB)
# ...
#         Using cached cython-3.2.5-py3-none-any.whl.metadata (6.9 kB)
# ...
#         Using cached numpy-2.4.6.tar.gz (20.7 MB)
#         Installing build dependencies: started
#         Installing build dependencies: finished with status 'done'
#         Getting requirements to build wheel: started
#         Getting requirements to build wheel: finished with status 'done'
#         Installing backend dependencies: started
# ...

# %%
import pandas

df1 = np.loadtxt('F0001CH1.CSV', header=None, nrows=20)
df3 = np.loadtxt('F0001CH3.CSV', header=None, nrows=20)

print("CH1 Data:")
print(df1.head(10))
print("\nCH3 Data:")
print(df3.head(10))
# Out:
# Running cells with 'Python 3.15.0' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Users/hasib/AppData/Roaming/uv/python/cpython-3.15.0a5-windows-x86_64-none/python.exe -m pip install ipykernel -U --user --force-reinstall'
